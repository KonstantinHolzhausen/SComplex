# %%
import numpy as np 
import pandas as pd 
import os 
import gudhi as gd

from data_processor import data_processor as dp
from metrics import metrics as met
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform
from scipy.stats import pearsonr
from sklearn.preprocessing import StandardScaler

from sklearn.cluster import AgglomerativeClustering
from mpl_toolkits.mplot3d import Axes3D
from hyppo.independence import Hsic
from matplotlib import cm
from dtw import *
from sklearn.cluster import AgglomerativeClustering
from collections import defaultdict
from src import complex_processing as cp 
from src import report_summary_sc as rs
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %% [markdown]
# # Data Ingestion
# - This is the most manual part of the jupyter notebook (data ingestion and scaling) depending on the system to be analyzed. Main objective is to just have all data injested before the next section. Data in the following cells is used as a placeholder for data I used and will include as an example

# %%
file_path = '/home/manret/SComplex/data/data_three_body/three_body_histories.csv'
df = pd.read_csv(file_path)
df.drop(["t","a1x","a2x","a3x","a1y","a2y","a3y"], axis=1, inplace=True)

# %%
print( "Number of columns in data to be analyzed is: ", len(df.columns))
print("Following Columns have been used: ", df.columns.tolist())
# Out:
# Number of columns in data to be analyzed is:  12
# Following Columns have been used:  ['r1x', 'r2x', 'r3x', 'v1x', 'v2x', 'v3x', 'r1y', 'r2y', 'r3y', 'v1y', 'v2y', 'v3y']

# %% [markdown]
# ### Cleaning: Clean up just to take away constant columns and time column

# %%
#Columns to drop for now since they dont mean too much to me but will keep it in the sim config. this takes away single value columns and 0 value columns. 
unique_and_zero_columns = df.columns[(df.nunique() == 1) | (df == 0).all()]
print("Columns to be dropped due to low variance or zero values:", unique_and_zero_columns)
df_cleaned = df.drop(columns=unique_and_zero_columns)
#Will also take away the redudant sway and surge columns for ground since there is no real current water and ground are exactly the same
df_cleaned = df_cleaned.loc[:, ~df_cleaned.columns.str.contains('ground', case=False)]
print("Columns to be used after cleaning for analysis:", df_cleaned.columns.tolist(), "Amount of columns to be used in analysis", len(df_cleaned.columns))
# Out:
# Columns to be dropped due to low variance or zero values: Index([], dtype='object')
# Columns to be used after cleaning for analysis: ['r1x', 'r2x', 'r3x', 'v1x', 'v2x', 'v3x', 'r1y', 'r2y', 'r3y', 'v1y', 'v2y', 'v3y'] Amount of columns to be used in analysis 12

# %% [markdown]
# ### Scaling: Scale all signals and normalize them for correlational and distance measures.

# %%
df_cleaned=df_cleaned.iloc[30:]
scaler = StandardScaler()
df_norm=pd.DataFrame(scaler.fit_transform(df_cleaned), columns=df_cleaned.columns)
results_df=cp.compute_pairwise_metrics(df_norm)

# %%
#results_df=cp.dtw_fix(results_df)

# %% [markdown]
# ### Processing and creating the rips complex based on 3 different metrics for comparison
# -  HSIC (independence criteria)
# -  Normal correlation
# -  Distance Correlation for improved correlational measure on non-linear correlation (remember to add reference for 1 and3)

# %%
# HSIC correlation-based complex
print("General total time series data ")
constant_metrics_dict=cp.create_metric_matrix(results_df)
#simplex_cor, diag_cor = cp.build_rips_complex(constant_metrics_dict["pearson_dist"])
#simplex_dcor, diag_dcor = cp.build_rips_complex(constant_metrics_dict["dcor_dist"])
#simplex_dtw, diag_dtw = cp.build_rips_complex(constant_metrics_dict["dtw_dist"])
# Out:
# General total time series data

# %%
simplex_hsic, diag_hsic = cp.build_rips_complex(constant_metrics_dict["hsic_dist"])

gd.plot_persistence_barcode(simplex_hsic.persistence())
#gd.plot_persistence_barcode(simplex_cor.persistence())
#gd.plot_persistence_barcode(simplex_dcor.persistence())
#gd.plot_persistence_barcode(simplex_dtw.persistence())
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Summary and interpretation for persistence feature in the table
# - Dimensions: 0 implies an individual vertex/signal, 1 is a persistent edge connecting two signals, 2 is a triangle connecting 3 vertices and so forth.
# - Persistence refers to individual permenence. Thus the greater the lifetime (death-birth) the greater the importance to the overall system. With this we can measure the complexity of the structure by its dimension and its relative importance by its lifetime
# - Persistent features dont disappear totally but rather merge with other features driven by its distance metric.
# - When speaking of a feature death in reality we are speaking of what they merge into.

# %%
rs.describe_persistence_features_table(simplex_dtw, df_cleaned.columns)
# Out:
#     Feature_ID  Dimension  Birth_Time Death_Time  Lifetime  \
# 0           45          0    0.000000          ∞         ∞
# 1           57          0    0.000000          ∞         ∞
# 2           46          0    0.000000   0.546428  0.546428
# 3           47          0    0.000000   0.519732  0.519732
# 4           48          0    0.000000   0.516265  0.516265
# 5           49          0    0.000000   0.498633  0.498633
# 6           50          0    0.000000    0.48888   0.48888
# 7           51          0    0.000000   0.481619  0.481619
# 8           52          0    0.000000   0.473286  0.473286
# 9           53          0    0.000000   0.460789  0.460789
# 10          54          0    0.000000   0.455943  0.455943
# 11          55          0    0.000000   0.443336  0.443336
# 12          56          0    0.000000   0.442009  0.442009
# 13           0          2    0.556351   0.716386  0.160035
# 14           1          2    0.556351   0.716386  0.160035
# 15           2          2    0.568351   0.723411   0.15506
# 16           3          2    0.556351   0.710601   0.15425
# 17           4          2    0.570043   0.720863   0.15082
# 18           5          2    0.575556   0.723411  0.147855
# 19           6          2    0.575556   0.720863  0.145307
# 20           7          2    0.572322   0.710601  0.138279
# 21           8          2    0.575556   0.710601  0.135044
# 22           9          2    0.570179   0.701968  0.131788
# 23          10          2    0.584700   0.707673  0.122973
# 24          11          2    0.598062   0.716386  0.118324
# 25          12          2    0.584608   0.701968  0.117359
# 26          13          2    0.584608   0.701968  0.117359
# 27          28          1    0.451359   0.554288  0.102929
# 28          15          2    0.607305   0.707673  0.100368
# 29          14          2    0.607305   0.707673  0.100368
# 30          16          2    0.618273   0.716386  0.098113
# 31          17          2    0.618273   0.710601  0.092328
# 32          18          2    0.618273   0.707673    0.0894
# 33          19          2    0.618273   0.701968  0.083695
# 34          20          2    0.598062   0.667011   0.06895
# 35          29          1    0.468257   0.536952  0.068695
# 36          30          1    0.491377   0.554447  0.063071
# 37          31          1    0.524637     0.5847  0.060063
# 38          21          2    0.618273   0.667011  0.048739
# 39          32          1    0.508946   0.554288  0.045341
# 40          33          1    0.526605   0.570179  0.043574
# 41          34          1    0.512165   0.554288  0.042123
# 42          35          1    0.468722   0.509948  0.041226
# 43          36          1    0.513516   0.551877  0.038361
# 44          37          1    0.549477   0.580822  0.031344
# 45          22          2    0.635690   0.667011  0.031322
# 46          23          2    0.635690   0.667011  0.031322
# 47          38          1    0.519327   0.546683  0.027356
# 48          39          1    0.511108   0.536952  0.025844
# 49          40          1    0.556708   0.580822  0.024113
# 50          41          1    0.532646   0.556351  0.023705
# 51          42          1    0.538378   0.556351  0.017973
# 52          25          2    0.659222   0.667011   0.00779
# 53          24          2    0.659222   0.667011   0.00779
#
#                                            Birth_From  \
# 0   Triangle formed by 'pid_derivative', 'x_beam',...
# 1                                       Node 'omega2'
# 2   Triangle formed by 'pid_derivative', 'x_beam',...
# 3   Triangle formed by 'pid_integral', 'error', 't...
# 4   Triangle formed by 'pid_integral', 'error', 't...
# 5      Triangle formed by 'error', 'x_beam', 'theta2'
# 6    Triangle formed by 'domega2', 'x_beam', 'theta2'
# 7   Triangle formed by 'pid_integral', 'domega1', ...
# 8   Triangle formed by 'pid_integral', 'domega2', ...
# 9      Triangle formed by 'error', 'x_beam', 'theta1'
# 10  Triangle formed by 'pid_derivative', 'pid_inte...
# 11   Triangle formed by 'domega2', 'x_beam', 'theta1'
# 12  Triangle formed by 'pid_integral', 'domega2', ...
# 13                                     Node 'domega1'
# 14                                     Node 'domega2'
# 15                                Node 'pid_integral'
# 16                                      Node 'theta2'
# 17                                      Node 'v_beam'
# 18                                     Node 'forcing'
# 19                                      Node 'x_beam'
# 20                                      Node 'theta1'
# 21                              Node 'pid_derivative'
# 22                Edge between 'domega2' and 'v_beam'
# 23                                       Node 'error'
# 24                                      Node 'omega1'
# 25                Edge between 'domega2' and 'x_beam'
# 26                     Edge between 'dv' and 'theta2'
# 27                 Edge between 'theta2' and 'omega1'
# 28         Edge between 'pid_derivative' and 'v_beam'
# 29                  Edge between 'error' and 'theta2'
# 30                                          Node 'dv'
# 31         Edge between 'pid_derivative' and 'x_beam'
# 32                  Edge between 'error' and 'x_beam'
# 33          Edge between 'pid_integral' and 'domega2'
# 34                  Edge between 'error' and 'v_beam'
# 35   Triangle formed by 'domega2', 'v_beam', 'omega2'
# 36        Triangle formed by 'dv', 'v_beam', 'omega2'
# 37     Triangle formed by 'error', 'v_beam', 'omega2'
# 38   Edge between 'pid_derivative' and 'pid_integral'
# 39  Triangle formed by 'pid_integral', 'domega2', ...
# 40  Triangle formed by 'pid_integral', 'dv', 'omega2'
# 41  Triangle formed by 'pid_integral', 'error', 'o...
# 42  Triangle formed by 'pid_derivative', 'v_beam',...
# 43  Triangle formed by 'pid_derivative', 'pid_inte...
# 44        Triangle formed by 'dv', 'v_beam', 'theta1'
# 45                Edge between 'domega2' and 'theta1'
# 46                 Edge between 'x_beam' and 'omega1'
# 47       Triangle formed by 'forcing', 'dv', 'v_beam'
# 48  Triangle formed by 'pid_derivative', 'pid_inte...
# 49  Triangle formed by 'pid_integral', 'dv', 'theta1'
# 50    Triangle formed by 'v_beam', 'omega1', 'theta1'
# 51   Triangle formed by 'forcing', 'v_beam', 'omega1'
# 52                     Edge between 'dv' and 'v_beam'
# 53                     Edge between 'dv' and 'x_beam'
#
#                                            Death_From
# 0   3D simplex with nodes 'error', 'dv', 'v_beam',...
# 1                                ∞ (persists forever)
# 2   3D simplex with nodes 'error', 'forcing', 'dv'...
# 3   3D simplex with nodes 'pid_integral', 'error',...
# 4   3D simplex with nodes 'pid_integral', 'error',...
# 5   3D simplex with nodes 'forcing', 'domega1', 'v...
# 6   3D simplex with nodes 'forcing', 'domega2', 'v...
# 7   3D simplex with nodes 'pid_integral', 'forcing...
# 8   3D simplex with nodes 'pid_integral', 'forcing...
# 9   3D simplex with nodes 'domega1', 'v_beam', 'th...
# 10  3D simplex with nodes 'pid_integral', 'domega1...
# 11  3D simplex with nodes 'domega2', 'v_beam', 'th...
# 12  3D simplex with nodes 'pid_integral', 'domega2...
# 13                Edge between 'domega1' and 'theta2'
# 14                Edge between 'domega2' and 'theta2'
# 15          Edge between 'pid_integral' and 'domega1'
# 16                Edge between 'domega1' and 'v_beam'
# 17                Edge between 'domega1' and 'x_beam'
# 18               Edge between 'forcing' and 'domega1'
# 19                Edge between 'domega1' and 'theta1'
# 20            Edge between 'pid_integral' and 'error'
# 21         Edge between 'pid_derivative' and 'theta2'
# 22  Triangle formed by 'forcing', 'domega2', 'v_beam'
# 23           Edge between 'pid_integral' and 'omega1'
# 24               Edge between 'pid_integral' and 'dv'
# 25   Triangle formed by 'domega2', 'v_beam', 'theta2'
# 26        Triangle formed by 'dv', 'v_beam', 'theta2'
# 27  Triangle formed by 'pid_integral', 'forcing', ...
# 28  Triangle formed by 'pid_derivative', 'v_beam',...
# 29     Triangle formed by 'error', 'v_beam', 'theta2'
# 30                 Edge between 'v_beam' and 'omega2'
# 31  Triangle formed by 'pid_derivative', 'forcing'...
# 32    Triangle formed by 'error', 'forcing', 'v_beam'
# 33  Triangle formed by 'pid_integral', 'forcing', ...
# 34  Triangle formed by 'pid_integral', 'error', 'f...
# 35  3D simplex with nodes 'domega2', 'v_beam', 'om...
# 36  3D simplex with nodes 'dv', 'v_beam', 'omega2'...
# 37  3D simplex with nodes 'error', 'v_beam', 'omeg...
# 38  Triangle formed by 'pid_derivative', 'pid_inte...
# 39  3D simplex with nodes 'pid_integral', 'domega2...
# 40  3D simplex with nodes 'pid_integral', 'dv', 'o...
# 41  3D simplex with nodes 'pid_integral', 'error',...
# 42  3D simplex with nodes 'pid_derivative', 'v_bea...
# 43  3D simplex with nodes 'pid_derivative', 'pid_i...
# 44  3D simplex with nodes 'pid_derivative', 'dv', ...
# 45   Triangle formed by 'domega2', 'v_beam', 'theta1'
# 46   Triangle formed by 'domega1', 'x_beam', 'theta2'
# 47  3D simplex with nodes 'pid_derivative', 'forci...
# 48  3D simplex with nodes 'pid_derivative', 'pid_i...
# 49  3D simplex with nodes 'pid_derivative', 'pid_i...
# 50  3D simplex with nodes 'dv', 'v_beam', 'theta2'...
# 51  3D simplex with nodes 'forcing', 'dv', 'v_beam...
# 52  Triangle formed by 'pid_integral', 'forcing', ...
# 53        Triangle formed by 'dv', 'x_beam', 'theta2'

# %% [markdown]
# # Data visualization of the structure
# - The next plots is shown for a very specific correlation metric and filtration threshold, play with different thresholds and correlation metrics to see how the simplicial complex changes.

# %%
persistence_information=rs.create_persistence_information(simplex_dtw)
rs.visualize_clustered_simplicial_complex(simplex_dtw,persistence_information, df_cleaned.columns, constant_metrics_dict["dtw_dist"], filtration_threshold=0.58)
# Out:
# /home/manret/SComplex/.venv/lib/python3.10/site-packages/scipy/cluster/hierarchy.py:796: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/manret/SComplex/src/report_summary_sc.py:180: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   triangle = plt.Polygon(triangle_points, color="lightgreen", edgecolor="black", alpha=0.5)
